# %% [markdown]
# <a href="https://colab.research.google.com/github/aichaag/projet-auth-qr-otp/blob/main/IDS_IA_Projet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-26703759-1e8d-4a1e-a659-ed5280701fb4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26703759-1e8d-4a1e-a659-ed5280701fb4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d cicdataset/cicids2017
# Out:
# 403 Client Error: Forbidden for url: https://api.kaggle.com/v1/datasets.DatasetApiService/GetDatasetMetadata

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/IDS_Dataset/MachineLearningCSV.zip" -d /content/cicids2017_data
# Out:
# Archive:  /content/drive/MyDrive/IDS_Dataset/MachineLearningCSV.zip
#    creating: /content/cicids2017_data/MachineLearningCVE/
#   inflating: /content/cicids2017_data/MachineLearningCVE/Wednesday-workingHours.pcap_ISCX.csv
#   inflating: /content/cicids2017_data/MachineLearningCVE/Tuesday-WorkingHours.pcap_ISCX.csv
#   inflating: /content/cicids2017_data/MachineLearningCVE/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv
#   inflating: /content/cicids2017_data/MachineLearningCVE/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv
#   inflating: /content/cicids2017_data/MachineLearningCVE/Monday-WorkingHours.pcap_ISCX.csv
#   inflating: /content/cicids2017_data/MachineLearningCVE/Friday-WorkingHours-Morning.pcap_ISCX.csv
#   inflating: /content/cicids2017_data/MachineLearningCVE/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv
#   inflating: /content/cicids2017_data/MachineLearningCVE/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv

# %%
import os

# Lister les fichiers CSV disponibles
fichiers = os.listdir('/content/cicids2017_data')
for f in fichiers:
    print(f)
# Out:
# MachineLearningCVE

# %%
import pandas as pd

# On commence par un seul fichier pour explorer sa structure
df = pd.read_csv('/content/cicids2017_data/MachineLearningCVE/Monday-WorkingHours.pcap_ISCX.csv')

# Dimensions du tableau (lignes, colonnes)
print("Dimensions :", df.shape)

# Aperçu des 5 premières lignes
df.head()
# Out:
# Dimensions : (529918, 79)
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0              49188               4                   2
# 1              49188               1                   2
# 2              49188               1                   2
# 3              49188               1                   2
# 4              49486               3                   2
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        0                           12
# 1                        0                           12
# 2                        0                           12
# 3                        0                           12
# 4                        0                           12
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                       6
# 1                             0                       6
# 2                             0                       6
# ...

# %%
# Liste complète des colonnes
print(df.columns.tolist())

# Vérifier les valeurs uniques de la colonne Label
print(df['Label'].value_counts())
# Out:
# [' Destination Port', ' Flow Duration', ' Total Fwd Packets', ' Total Backward Packets', 'Total Length of Fwd Packets', ' Total Length of Bwd Packets', ' Fwd Packet Length Max', ' Fwd Packet Length Min', ' Fwd Packet Length Mean', ' Fwd Packet Length Std', 'Bwd Packet Length Max', ' Bwd Packet Length Min', ' Bwd Packet Length Mean', ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s', ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min', 'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max', ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std', ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags', ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length', ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s', ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean', ' Packet Length Std', ' Packet Length Variance', 'FIN Flag Count', ' SYN Flag Count', ' RST Flag Count', ' PSH Flag Count', ' ACK Flag Count', ' URG Fla
# ...

# %%
# Afficher les noms de colonnes tels quels, avec leurs espaces visibles
print([col for col in df.columns if 'abel' in col.lower()])
# Out:
# [' Label']

# %%
# Nettoyer tous les noms de colonnes (retirer les espaces superflus)
df.columns = df.columns.str.strip()

# Vérifier que ça a marché
print('Label' in df.columns)

# Voir les valeurs de la colonne Label
print(df['Label'].value_counts())
# Out:
# True
# Label
# BENIGN    529918
# Name: count, dtype: int64
